# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/Articles/Satellite_Image_TimeSeriesClassification/
# Out:
# /content/drive/My Drive/Articles/Satellite_Image_TimeSeriesClassification

# %%
pip install torchnet
# Out:
# Collecting torchnet
#   Downloading torchnet-0.0.4.tar.gz (23 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (from torchnet) (2.1.0+cu121)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from torchnet) (1.16.0)
# Collecting visdom (from torchnet)
#   Downloading visdom-0.2.4.tar.gz (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 30.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (4.9.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (3.1.3)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch->torchnet) (2.1.0)
# Requirement already satisfied: numpy>=1.8 in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (1.23.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (1.11.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (2.31.0)
# Requirement already satisfied: tornado in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (6.3.2)
# Collecting jsonpatch (from visdom->torchnet)
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (1.7.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from visdom->torchnet) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch->torchnet) (2.1.5)
# Collecting jsonpointer>=1.9 (from jsonpatch->visdom->torchnet)
#   Downloading jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->visdom->torchnet) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->visdom->torchnet) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->visdom->torchnet) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->visdom->torchnet) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch->torchnet) (1.3.0)
# Building wheels for collected packages: torchnet, visdom
#   Building wheel for torchnet (setup.py) ... done
#   Created wheel for torchnet: filename=torchnet-0.0.4-py3-none-any.whl size=29728 sha256=49ddac07c3c9d684f2638b72ef458652b5a4d9abfe24da5be85006cb9ceae404
#   Stored in directory: /root/.cache/pip/wheels/f7/ae/94/9f5edd6871983f30967ad11d60ef434c3d1b007654de4c8065
#   Building wheel for visdom (setup.py) ... done
#   Created wheel for visdom: filename=visdom-0.2.4-py3-none-any.whl size=1408194 sha256=a39d23a5b6b895c552346cd7d752457602a93012a051e0077ea2e0f4fd1bcca4
#   Stored in directory: /root/.cache/pip/wheels/42/29/49/5bed207bac4578e4d2c0c5fc0226bfd33a7e2953ea56356855
# Successfully built torchnet visdom
# Installing collected packages: jsonpointer, jsonpatch, visdom, torchnet
# Successfully installed jsonpatch-1.33 jsonpointer-2.4 torchnet-0.0.4 visdom-0.2.4

# %%
import torch
import torch.utils.data as data
import torchnet as tnt
import numpy as np
from sklearn.model_selection import KFold
from sklearn.metrics import confusion_matrix
import os
import json
import pickle as pkl
import argparse
import pprint

# %%
from models.stclassifier import PseTae
from dataset import PixelSetData, PixelSetData_preloaded
from learning.focal_loss import FocalLoss
from learning.weight_init import weight_init
from learning.metrics import mIou, confusion_matrix_analysis

# %%
def train_epoch(model, optimizer, criterion, data_loader, device, args):
    acc_meter = tnt.meter.ClassErrorMeter(accuracy=True)
    loss_meter = tnt.meter.AverageValueMeter()
    y_true = []
    y_pred = []

    for i, (x, y) in enumerate(data_loader):

        y_true.extend(list(map(int, y)))

        x = recursive_todevice(x, device)
        y = y.to(device)

        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y.long())
        loss.backward()
        optimizer.step()

        pred = out.detach()
        y_p = pred.argmax(dim=1).cpu().numpy()
        y_pred.extend(list(y_p))
        acc_meter.add(pred, y)
        loss_meter.add(loss.item())

        if (i + 1) % args['display_step'] == 0:
            print('Step [{}/{}], Loss: {:.4f}, Acc : {:.2f}'.format(i + 1, len(data_loader), loss_meter.value()[0],
                                                                    acc_meter.value()[0]))

    epoch_metrics = {'train_loss': loss_meter.value()[0],
                     'train_accuracy': acc_meter.value()[0],
                     'train_IoU': mIou(y_true, y_pred, n_classes=args['num_classes'])}

    return epoch_metrics


def evaluation(model, criterion, loader, device, args, mode='val'):
    y_true = []
    y_pred = []

    acc_meter = tnt.meter.ClassErrorMeter(accuracy=True)
    loss_meter = tnt.meter.AverageValueMeter()

    for (x, y) in loader:
        y_true.extend(list(map(int, y)))
        x = recursive_todevice(x, device)
        y = y.to(device)

        with torch.no_grad():
            prediction = model(x)
            loss = criterion(prediction, y)

        acc_meter.add(prediction, y)
        loss_meter.add(loss.item())

        y_p = prediction.argmax(dim=1).cpu().numpy()
        y_pred.extend(list(y_p))

    metrics = {'{}_accuracy'.format(mode): acc_meter.value()[0],
               '{}_loss'.format(mode): loss_meter.value()[0],
               '{}_IoU'.format(mode): mIou(y_true, y_pred, args['num_classes'])}

    if mode == 'val':
        return metrics
    elif mode == 'test':
        return metrics, confusion_matrix(y_true, y_pred, labels=list(range(args['num_classes'])))


def get_loaders(dt, kfold, args):
    indices = list(range(len(dt)))
    np.random.shuffle(indices)

    kf = KFold(n_splits=kfold, shuffle=False)
    indices_seq = list(kf.split(list(range(len(dt)))))
    ntest = len(indices_seq[0][1])

    loader_seq = []
    for trainval, test_indices in indices_seq:
        trainval = [indices[i] for i in trainval]
        test_indices = [indices[i] for i in test_indices]

        validation_indices = trainval[-ntest:]
        train_indices = trainval[:-ntest]

        train_sampler = data.sampler.SubsetRandomSampler(train_indices)
        validation_sampler = data.sampler.SubsetRandomSampler(validation_indices)
        test_sampler = data.sampler.SubsetRandomSampler(test_indices)

        train_loader = data.DataLoader(dt, batch_size=args['batch_size'],
                                       sampler=train_sampler,
                                       num_workers=args['num_workers'])
        validation_loader = data.DataLoader(dt, batch_size=args['batch_size'],
                                            sampler=validation_sampler,
                                            num_workers=args['num_workers'])
        test_loader = data.DataLoader(dt, batch_size=args['batch_size'],
                                      sampler=test_sampler,
                                      num_workers=args['num_workers'])

        loader_seq.append((train_loader, validation_loader, test_loader))
    return loader_seq


def recursive_todevice(x, device):
    if isinstance(x, torch.Tensor):
        return x.to(device)
    else:
        return [recursive_todevice(c, device) for c in x]


def prepare_output(args):
    os.makedirs(args['res_dir'], exist_ok=True)
    for fold in range(1, args['kfold'] + 1):
        os.makedirs(os.path.join(args['res_dir'], 'Fold_{}'.format(fold)), exist_ok=True)


def checkpoint(fold, log, args):
    with open(os.path.join(args['res_dir'], 'Fold_{}'.format(fold), 'trainlog.json'), 'w') as outfile:
        json.dump(log, outfile, indent=4)


def save_results(fold, metrics, conf_mat, args):
    with open(os.path.join(args['res_dir'], 'Fold_{}'.format(fold), 'test_metrics.json'), 'w') as outfile:
        json.dump(metrics, outfile, indent=4)
    pkl.dump(conf_mat, open(os.path.join(args['res_dir'], 'Fold_{}'.format(fold), 'conf_mat.pkl'), 'wb'))


def overall_performance(args):
    cm = np.zeros((args['num_classes'], args['num_classes']))
    for fold in range(1, args['kfold'] + 1):
        cm += pkl.load(open(os.path.join(args['res_dir'], 'Fold_{}'.format(fold), 'conf_mat.pkl'), 'rb'))

    _, perf = confusion_matrix_analysis(cm)

    print('Overall performance:')
    print('Acc: {},  IoU: {}'.format(perf['Accuracy'], perf['MACRO_IoU']))

    with open(os.path.join(args['res_dir'], 'overall.json'), 'w') as file:
        file.write(json.dumps(perf, indent=4))


def main(args):
    np.random.seed(args['rdm_seed'])
    torch.manual_seed(args['rdm_seed'])
    prepare_output(args)
    mean_std = pkl.load(open(args['dataset_folder'] + '/S2-2017-T31TFM-meanstd.pkl.pkl', 'rb'))


    #mean_std = pkl.load(open('/content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/dataset_folder/S2-2017-T31TFM-meanstd.pkl', 'rb'))




    extra = 'geomfeat' if args['geomfeat'] else None

    if args['preload']:
        dt = PixelSetData_preloaded(args['dataset_folder'], labels='label_44class', npixel=args['npixel'],
                          sub_classes=[1, 3, 4, 5, 6, 8, 9, 12, 13, 14, 16, 18, 19, 23, 28, 31, 33, 34, 36, 39],
                          norm=mean_std,
                          extra_feature=extra)
    else:
        dt = PixelSetData(args['dataset_folder'], labels='label_44class', npixel=args['npixel'],
                          sub_classes=[1, 3, 4, 5, 6, 8, 9, 12, 13, 14, 16, 18, 19, 23, 28, 31, 33, 34, 36, 39],
                          norm=mean_std,
                          extra_feature=extra)
    device = torch.device(args['device'])

    loaders = get_loaders(dt, args['kfold'], args)
    for fold, (train_loader, val_loader, test_loader) in enumerate(loaders):
        print('Starting Fold {}'.format(fold + 1))
        print('Train {}, Val {}, Test {}'.format(len(train_loader), len(val_loader), len(test_loader)))

        model_args= dict(input_dim=args['input_dim'], mlp1=args['mlp1'], pooling=args['pooling'],
                            mlp2=args['mlp2'], n_head=args['n_head'], d_k=args['d_k'], mlp3=args['mlp3'],
                            dropout=args['dropout'], T=args['T'], len_max_seq=args['lms'],
                            positions=dt.date_positions if args['positions'] == 'bespoke' else None,
                            mlp4=args['mlp4'])

        if args['geomfeat']:
            model_args.update(with_extra=True, extra_size=4)
        else:
            model_args.update(with_extra=False, extra_size=None)

        model = PseTae(**model_args)

        print(model.param_ratio())

        model = model.to(device)
        model.apply(weight_init)
        optimizer = torch.optim.Adam(model.parameters())
        criterion = FocalLoss(args['gamma'])

        trainlog = {}



        best_mIoU = 0
        for epoch in range(1, args['epochs'] + 1):
            print('EPOCH {}/{}'.format(epoch, args['epochs']))

            model.train()
            train_metrics = train_epoch(model, optimizer, criterion, train_loader, device=device, args=args)

            print('Validation . . . ')
            model.eval()
            val_metrics = evaluation(model, criterion, val_loader, device=device, args=args, mode='val')

            print('Loss {:.4f},  Acc {:.2f},  IoU {:.4f}'.format(val_metrics['val_loss'], val_metrics['val_accuracy'],
                                                                 val_metrics['val_IoU']))

            trainlog[epoch] = {**train_metrics, **val_metrics}
            checkpoint(fold + 1, trainlog, args)

            if val_metrics['val_IoU'] >= best_mIoU:
                best_mIoU = val_metrics['val_IoU']
                torch.save({'epoch': epoch, 'state_dict': model.state_dict(),
                            'optimizer': optimizer.state_dict()},
                           os.path.join(args['res_dir'], 'Fold_{}'.format(fold + 1), 'model.pth.tar'))

        print('Testing best epoch . . .')
        model.load_state_dict(
            torch.load(os.path.join(args['res_dir'], 'Fold_{}'.format(fold + 1), 'model.pth.tar'))['state_dict'])
        model.eval()

        test_metrics, conf_mat = evaluation(model, criterion, test_loader, device=device, mode='test', args=args)

        print('Loss {:.4f},  Acc {:.2f},  IoU {:.4f}'.format(test_metrics['test_loss'], test_metrics['test_accuracy'],
                                                             test_metrics['test_IoU']))
        save_results(fold + 1, test_metrics, conf_mat, args)

    overall_performance(args)

# %%
if __name__ == '__main__':

    parser = argparse.ArgumentParser()

    # Set-up parameters
    parser.add_argument('--dataset_folder', default='/content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/dataset_folder', type=str,
                        help='Path to the folder where the results are saved.')
    parser.add_argument('--res_dir', default='./results', help='Path to the folder where the results should be stored')
    parser.add_argument('--num_workers', default=8, type=int, help='Number of data loading workers')
    parser.add_argument('--rdm_seed', default=1, type=int, help='Random seed')
    parser.add_argument('--device', default='cuda', type=str,
                        help='Name of device to use for tensor computations (cuda/cpu)')
    parser.add_argument('--display_step', default=50, type=int,
                        help='Interval in batches between display of training metrics')
    parser.add_argument('--preload', dest='preload', action='store_true',
                        help='If specified, the whole dataset is loaded to RAM at initialization')
    parser.set_defaults(preload=False)

    # Training parameters
    parser.add_argument('--kfold', default=5, type=int, help='Number of folds for cross validation')
    parser.add_argument('--epochs', default=100, type=int, help='Number of epochs per fold')
    parser.add_argument('--batch_size', default=128, type=int, help='Batch size')
    parser.add_argument('--lr', default=0.001, type=float, help='Learning rate')
    parser.add_argument('--gamma', default=1, type=float, help='Gamma parameter of the focal loss')
    parser.add_argument('--npixel', default=64, type=int, help='Number of pixels to sample from the input images')

    # Architecture Hyperparameters
    ## PSE
    parser.add_argument('--input_dim', default=10, type=int, help='Number of channels of input images')
    parser.add_argument('--mlp1', default='[10,32,64]', type=str, help='Number of neurons in the layers of MLP1')
    parser.add_argument('--pooling', default='mean_std', type=str, help='Pixel-embeddings pooling strategy')
    parser.add_argument('--mlp2', default='[132,128]', type=str, help='Number of neurons in the layers of MLP2')
    parser.add_argument('--geomfeat', default=1, type=int,
                        help='If 1 the precomputed geometrical features (f) are used in the PSE.')

    ## TAE
    parser.add_argument('--n_head', default=4, type=int, help='Number of attention heads')
    parser.add_argument('--d_k', default=32, type=int, help='Dimension of the key and query vectors')
    parser.add_argument('--mlp3', default='[512,128,128]', type=str, help='Number of neurons in the layers of MLP3')
    parser.add_argument('--T', default=1000, type=int, help='Maximum period for the positional encoding')
    parser.add_argument('--positions', default='bespoke', type=str,
                        help='Positions to use for the positional encoding (bespoke / order)')
    parser.add_argument('--lms', default=None, type=int,
                        help='Maximum sequence length for positional encoding (only necessary if positions == order)')
    parser.add_argument('--dropout', default=0.2, type=float, help='Dropout probability')

    ## Classifier
    parser.add_argument('--num_classes', default=20, type=int, help='Number of classes')
    parser.add_argument('--mlp4', default='[128, 64, 32, 20]', type=str, help='Number of neurons in the layers of MLP4')

# %%
    args= parser.parse_args(args=[])
    args= vars(args)
    for k, v in args.items():
        if 'mlp' in k:
            v = v.replace('[', '')
            v = v.replace(']', '')
            args[k] = list(map(int, v.split(',')))

    pprint.pprint(args)
    main(args)
# Out:
# {'T': 1000,
#  'batch_size': 128,
#  'd_k': 32,
#  'dataset_folder': '/content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/dataset_folder',
#  'device': 'cuda',
#  'display_step': 50,
#  'dropout': 0.2,
#  'epochs': 100,
#  'gamma': 1,
#  'geomfeat': 1,
#  'input_dim': 10,
#  'kfold': 5,
#  'lms': None,
#  'lr': 0.001,
#  'mlp1': [10, 32, 64],
#  'mlp2': [132, 128],
#  'mlp3': [512, 128, 128],
#  'mlp4': [128, 64, 32, 20],
#  'n_head': 4,
#  'npixel': 64,
#  'num_classes': 20,
#  'num_workers': 8,
#  'pooling': 'mean_std',
#  'positions': 'bespoke',
#  'preload': False,
#  'rdm_seed': 1,
#  'res_dir': './results'}
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Starting Fold 1
# Train 5, Val 2, Test 2
# TOTAL TRAINABLE PARAMETERS : 164116
# RATIOS: Spatial  12.1% , Temporal  81.0% , Classifier   6.8%
# None
# EPOCH 1/100
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validation . . .
# Loss 4.9130,  Acc 0.00,  IoU 0.0000
# EPOCH 2/100
# Validation . . .
# Loss 4.9013,  Acc 0.00,  IoU 0.0000
# EPOCH 3/100
# Validation . . .
# Loss 4.5986,  Acc 0.00,  IoU 0.0000
# EPOCH 4/100
# Validation . . .
# Loss 4.0633,  Acc 0.00,  IoU 0.0000
# EPOCH 5/100
# Validation . . .
# Loss 3.1234,  Acc 6.50,  IoU 0.0081
# EPOCH 6/100
# Validation . . .
# Loss 2.2466,  Acc 25.00,  IoU 0.0409
# EPOCH 7/100
# Validation . . .
# Loss 1.6827,  Acc 46.50,  IoU 0.0882
# EPOCH 8/100
# Validation . . .
# Loss 1.2236,  Acc 72.50,  IoU 0.2019
# EPOCH 9/100
# Validation . . .
# Loss 1.0297,  Acc 83.00,  IoU 0.2693
# EPOCH 10/100
# Validation . . .
# Loss 0.9024,  Acc 86.50,  IoU 0.3280
# EPOCH 11/100
# Validation . . .
# Loss 0.8041,  Acc 89.00,  IoU 0.3467
# EPOCH 12/100
# Validation . . .
# Loss 0.7224,  Acc 90.50,  IoU 0.3402
# EPOCH 13/100
# Validation . . .
# Loss 0.6557,  Acc 91.50,  IoU 0.3321
# EPOCH 14/100
# Validation . . .
# Loss 0.5915,  Acc 91.50,  IoU 0.3420
# EPOCH 15/100
# Validation . . .
# Loss 0.5429,  Acc 92.00,  IoU 0.3205
# EPOCH 16/100
# Validation . . .
# Loss 0.4969,  Acc 92.50,  IoU 0.4064
# EPOCH 17/100
# Validation . . .
# Loss 0.5107,  Acc 92.00,  IoU 0.3597
# EPOCH 18/100
# Validation . . .
# Loss 0.4307,  Acc 92.00,  IoU 0.3840
# EPOCH 19/100
# Validation . . .
# Loss 0.3976,  Acc 92.00,  IoU 0.3846
# EPOCH 20/100
# Validation . . .
# Loss 0.3461,  Acc 92.50,  IoU 0.3329
# EPOCH 21/100
# Validation . . .
# Loss 0.4070,  Acc 92.00,  IoU 0.3745
# EPOCH 22/100
# Validation . . .
# Loss 0.3381,  Acc 92.50,  IoU 0.4027
# EPOCH 23/100
# Validation . . .
# Loss 0.3582,  Acc 92.50,  IoU 0.4167
# EPOCH 24/100
# Validation . . .
# Loss 0.3098,  Acc 93.00,  IoU 0.4217
# EPOCH 25/100
# Validation . . .
# Loss 0.3603,  Acc 93.50,  IoU 0.4396
# EPOCH 26/100
# Validation . . .
# Loss 0.2934,  Acc 93.50,  IoU 0.4247
# EPOCH 27/100
# Validation . . .
# Loss 0.3152,  Acc 94.00,  IoU 0.4376
# EPOCH 28/100
# Validation . . .
# Loss 0.2914,  Acc 94.00,  IoU 0.4227
# EPOCH 29/100
# Validation . . .
# Loss 0.2615,  Acc 94.00,  IoU 0.4236
# EPOCH 30/100
# Validation . . .
# Loss 0.2114,  Acc 95.00,  IoU 0.4267
# EPOCH 31/100
# Validation . . .
# Loss 0.2467,  Acc 95.00,  IoU 0.4403
# EPOCH 32/100
# Validation . . .
# Loss 0.2718,  Acc 94.00,  IoU 0.3916
# EPOCH 33/100
# Validation . . .
# Loss 0.2493,  Acc 95.00,  IoU 0.3955
# EPOCH 34/100
# Validation . . .
# Loss 0.2215,  Acc 95.50,  IoU 0.4252
# EPOCH 35/100
# Validation . . .
# Loss 0.2136,  Acc 96.50,  IoU 0.5330
# EPOCH 36/100
# Validation . . .
# Loss 0.2330,  Acc 96.00,  IoU 0.5115
# EPOCH 37/100
# Validation . . .
# Loss 0.2152,  Acc 95.50,  IoU 0.4068
# EPOCH 38/100
# Validation . . .
# Loss 0.2170,  Acc 95.00,  IoU 0.4603
# EPOCH 39/100
# Validation . . .
# Loss 0.2071,  Acc 95.50,  IoU 0.5046
# EPOCH 40/100
# Validation . . .
# Loss 0.2204,  Acc 95.50,  IoU 0.4623
# EPOCH 41/100
# Validation . . .
# Loss 0.2302,  Acc 96.00,  IoU 0.5136
# EPOCH 42/100
# Validation . . .
# Loss 0.1736,  Acc 95.50,  IoU 0.5068
# EPOCH 43/100
# Validation . . .
# Loss 0.1761,  Acc 95.50,  IoU 0.5068
# EPOCH 44/100
# Validation . . .
# Loss 0.1875,  Acc 95.00,  IoU 0.4424
# EPOCH 45/100
# Validation . . .
# Loss 0.1977,  Acc 96.00,  IoU 0.5294
# EPOCH 46/100
# Validation . . .
# Loss 0.1670,  Acc 95.50,  IoU 0.4623
# EPOCH 47/100
# Validation . . .
# Loss 0.1789,  Acc 96.50,  IoU 0.5136
# EPOCH 48/100
# Validation . . .
# Loss 0.2047,  Acc 96.00,  IoU 0.5102
# EPOCH 49/100
# Validation . . .
# Loss 0.1893,  Acc 95.50,  IoU 0.5258
# EPOCH 50/100
# Validation . . .
# Loss 0.2007,  Acc 96.00,  IoU 0.5509
# EPOCH 51/100
# Validation . . .
# Loss 0.1962,  Acc 95.50,  IoU 0.5473
# EPOCH 52/100
# Validation . . .
# Loss 0.1847,  Acc 95.00,  IoU 0.4885
# EPOCH 53/100
# Validation . . .
# Loss 0.2329,  Acc 94.00,  IoU 0.4508
# EPOCH 54/100
# Validation . . .
# Loss 0.2162,  Acc 94.50,  IoU 0.4850
# EPOCH 55/100
# Validation . . .
# Loss 0.2169,  Acc 95.00,  IoU 0.5065
# EPOCH 56/100
# Validation . . .
# Loss 0.2117,  Acc 95.00,  IoU 0.5065
# EPOCH 57/100
# Validation . . .
# Loss 0.2017,  Acc 94.50,  IoU 0.4850
# EPOCH 58/100
# Validation . . .
# Loss 0.2175,  Acc 95.00,  IoU 0.5065
# EPOCH 59/100
# Validation . . .
# Loss 0.2469,  Acc 95.00,  IoU 0.5065
# EPOCH 60/100
# Validation . . .
# Loss 0.2229,  Acc 94.50,  IoU 0.5192
# EPOCH 61/100
# Validation . . .
# Loss 0.2156,  Acc 95.50,  IoU 0.5262
# EPOCH 62/100
# Validation . . .
# Loss 0.2295,  Acc 96.00,  IoU 0.5115
# EPOCH 63/100
# Validation . . .
# Loss 0.2605,  Acc 95.50,  IoU 0.5079
# EPOCH 64/100
# Validation . . .
# Loss 0.2255,  Acc 95.50,  IoU 0.5033
# EPOCH 65/100
# Validation . . .
# Loss 0.2019,  Acc 95.00,  IoU 0.4803
# EPOCH 66/100
# Validation . . .
# Loss 0.2110,  Acc 95.00,  IoU 0.4392
# EPOCH 67/100
# Validation . . .
# Loss 0.2642,  Acc 94.50,  IoU 0.5142
# EPOCH 68/100
# Validation . . .
# Loss 0.2286,  Acc 94.50,  IoU 0.4882
# EPOCH 69/100
# Validation . . .
# Loss 0.2956,  Acc 93.50,  IoU 0.4360
# EPOCH 70/100
# Validation . . .
# Loss 0.2380,  Acc 95.00,  IoU 0.5455
# EPOCH 71/100
# Validation . . .
# Loss 0.2331,  Acc 95.00,  IoU 0.5455
# EPOCH 72/100
# Validation . . .
# Loss 0.1760,  Acc 94.50,  IoU 0.4982
# EPOCH 73/100
# Validation . . .
# Loss 0.2383,  Acc 95.00,  IoU 0.5010
# EPOCH 74/100
# Validation . . .
# Loss 0.2162,  Acc 95.00,  IoU 0.5010
# EPOCH 75/100
# Validation . . .
# Loss 0.2055,  Acc 94.00,  IoU 0.4796
# EPOCH 76/100
# Validation . . .
# Loss 0.2339,  Acc 94.00,  IoU 0.4942
# EPOCH 77/100
# Validation . . .
# Loss 0.2157,  Acc 94.50,  IoU 0.4519
# EPOCH 78/100
# Validation . . .
# Loss 0.2769,  Acc 94.50,  IoU 0.5155
# EPOCH 79/100
# Validation . . .
# Loss 0.2169,  Acc 94.50,  IoU 0.4974
# EPOCH 80/100
# Validation . . .
# Loss 0.2354,  Acc 94.50,  IoU 0.4977
# EPOCH 81/100
# Validation . . .
# Loss 0.2061,  Acc 94.50,  IoU 0.4735
# EPOCH 82/100
# Validation . . .
# Loss 0.2029,  Acc 95.00,  IoU 0.4867
# EPOCH 83/100
# Validation . . .
# Loss 0.1774,  Acc 94.50,  IoU 0.4974
# EPOCH 84/100
# Validation . . .
# Loss 0.2136,  Acc 95.50,  IoU 0.5305
# EPOCH 85/100
# Validation . . .
# Loss 0.1831,  Acc 95.50,  IoU 0.5303
# EPOCH 86/100
# Validation . . .
# Loss 0.2077,  Acc 96.00,  IoU 0.5340
# EPOCH 87/100
# Validation . . .
# Loss 0.2191,  Acc 96.00,  IoU 0.5340
# EPOCH 88/100
# Validation . . .
# Loss 0.2500,  Acc 95.50,  IoU 0.5030
# EPOCH 89/100
# Validation . . .
# Loss 0.2235,  Acc 95.50,  IoU 0.5030
# EPOCH 90/100
# Validation . . .
# Loss 0.1846,  Acc 95.50,  IoU 0.5044
# EPOCH 91/100
# Validation . . .
# Loss 0.1591,  Acc 95.00,  IoU 0.5010
# EPOCH 92/100
# Validation . . .
# Loss 0.2140,  Acc 95.00,  IoU 0.4996
# EPOCH 93/100
# Validation . . .
# Loss 0.2577,  Acc 95.00,  IoU 0.5010
# EPOCH 94/100
# Validation . . .
# Loss 0.2548,  Acc 95.00,  IoU 0.5178
# EPOCH 95/100
# Validation . . .
# Loss 0.2202,  Acc 95.00,  IoU 0.5453
# EPOCH 96/100
# Validation . . .
# Loss 0.2306,  Acc 95.50,  IoU 0.5486
# EPOCH 97/100
# Validation . . .
# Loss 0.2338,  Acc 95.50,  IoU 0.5486
# EPOCH 98/100
# Validation . . .
# Loss 0.2483,  Acc 95.50,  IoU 0.5486
# EPOCH 99/100
# Validation . . .
# Loss 0.2151,  Acc 96.50,  IoU 0.5558
# EPOCH 100/100
# Validation . . .
# Loss 0.3242,  Acc 92.00,  IoU 0.3927
# Testing best epoch . . .
# Loss 0.1631,  Acc 94.00,  IoU 0.5414
# Starting Fold 2
# Train 5, Val 2, Test 2
# TOTAL TRAINABLE PARAMETERS : 164116
# RATIOS: Spatial  12.1% , Temporal  81.0% , Classifier   6.8%
# None
# EPOCH 1/100
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validation . . .
# Loss 2.3184,  Acc 0.00,  IoU 0.0000
# EPOCH 2/100
# Validation . . .
# Loss 2.1484,  Acc 18.50,  IoU 0.0251
# EPOCH 3/100
# Validation . . .
# Loss 1.8726,  Acc 46.50,  IoU 0.0886
# EPOCH 4/100
# Validation . . .
# Loss 1.4772,  Acc 66.50,  IoU 0.1372
# EPOCH 5/100
# Validation . . .
# Loss 1.0770,  Acc 83.00,  IoU 0.1656
# EPOCH 6/100
# Validation . . .
# Loss 0.8840,  Acc 85.00,  IoU 0.1927
# EPOCH 7/100
# Validation . . .
# Loss 0.8288,  Acc 85.50,  IoU 0.1945
# EPOCH 8/100
# Validation . . .
# Loss 0.7244,  Acc 85.50,  IoU 0.2213
# EPOCH 9/100
# Validation . . .
# Loss 0.6905,  Acc 86.50,  IoU 0.2453
# EPOCH 10/100
# Validation . . .
# Loss 0.6553,  Acc 88.00,  IoU 0.2785
# EPOCH 11/100
# Validation . . .
# Loss 0.6222,  Acc 88.50,  IoU 0.2818
# EPOCH 12/100
# Validation . . .
# Loss 0.5664,  Acc 88.50,  IoU 0.2818
# EPOCH 13/100
# Validation . . .
# Loss 0.4590,  Acc 89.00,  IoU 0.2823
# EPOCH 14/100
# Validation . . .
# Loss 0.4583,  Acc 90.50,  IoU 0.2928
# EPOCH 15/100
# Validation . . .
# Loss 0.4475,  Acc 91.50,  IoU 0.3208
# EPOCH 16/100
# Validation . . .
# Loss 0.3835,  Acc 91.50,  IoU 0.3174
# EPOCH 17/100
# Validation . . .
# Loss 0.4220,  Acc 91.50,  IoU 0.3174
# EPOCH 18/100
# Validation . . .
# Loss 0.3597,  Acc 93.50,  IoU 0.4119
# EPOCH 19/100
# Validation . . .
# Loss 0.3531,  Acc 94.00,  IoU 0.4453
# EPOCH 20/100
# Validation . . .
# Loss 0.2824,  Acc 94.00,  IoU 0.4787
# EPOCH 21/100
# Validation . . .
# Loss 0.2607,  Acc 94.50,  IoU 0.4822
# EPOCH 22/100
# Validation . . .
# Loss 0.2737,  Acc 94.50,  IoU 0.4822
# EPOCH 23/100
# Validation . . .
# Loss 0.2425,  Acc 94.50,  IoU 0.4480
# EPOCH 24/100
# Validation . . .
# Loss 0.2877,  Acc 93.50,  IoU 0.4413
# EPOCH 25/100
# Validation . . .
# Loss 0.2593,  Acc 94.50,  IoU 0.4480
# EPOCH 26/100
# Validation . . .
# Loss 0.3034,  Acc 94.00,  IoU 0.4447
# EPOCH 27/100
# Validation . . .
# Loss 0.2748,  Acc 94.00,  IoU 0.4447
# EPOCH 28/100
# Validation . . .
# Loss 0.3036,  Acc 92.50,  IoU 0.4157
# EPOCH 29/100
# Validation . . .
# Loss 0.2859,  Acc 93.50,  IoU 0.4416
# EPOCH 30/100
# Validation . . .
# Loss 0.2558,  Acc 95.50,  IoU 0.5262
# EPOCH 31/100
# Validation . . .
# Loss 0.2351,  Acc 95.50,  IoU 0.5262
# EPOCH 32/100
# Validation . . .
# Loss 0.2174,  Acc 95.50,  IoU 0.5262
# EPOCH 33/100
# Validation . . .
# Loss 0.2326,  Acc 96.00,  IoU 0.5149
# EPOCH 34/100
# Validation . . .
# Loss 0.2783,  Acc 95.50,  IoU 0.5115
# EPOCH 35/100
# Validation . . .
# Loss 0.2307,  Acc 94.50,  IoU 0.4674
# EPOCH 36/100
# Validation . . .
# Loss 0.2551,  Acc 95.00,  IoU 0.4707
# EPOCH 37/100
# Validation . . .
# Loss 0.3087,  Acc 93.50,  IoU 0.4609
# EPOCH 38/100
# Validation . . .
# Loss 0.3281,  Acc 93.50,  IoU 0.4724
# EPOCH 39/100
# Validation . . .
# Loss 0.3134,  Acc 94.00,  IoU 0.4641
# EPOCH 40/100
# Validation . . .
# Loss 0.2773,  Acc 93.50,  IoU 0.4397
# EPOCH 41/100
# Validation . . .
# Loss 0.2705,  Acc 94.50,  IoU 0.4543
# EPOCH 42/100
# Validation . . .
# Loss 0.2403,  Acc 94.00,  IoU 0.4561
# EPOCH 43/100
# Validation . . .
# Loss 0.2095,  Acc 95.00,  IoU 0.4721
# EPOCH 44/100
# Validation . . .
# Loss 0.2496,  Acc 95.50,  IoU 0.4866
# EPOCH 45/100
# Validation . . .
# Loss 0.1790,  Acc 94.50,  IoU 0.4780
# EPOCH 46/100
# Validation . . .
# Loss 0.2091,  Acc 94.00,  IoU 0.4453
# EPOCH 47/100
# Validation . . .
# Loss 0.2205,  Acc 93.50,  IoU 0.4494
# EPOCH 48/100
# Validation . . .
# Loss 0.2037,  Acc 93.50,  IoU 0.4892
# EPOCH 49/100
# Validation . . .
# Loss 0.2468,  Acc 93.50,  IoU 0.4762
# EPOCH 50/100
# Validation . . .
# Loss 0.2119,  Acc 94.00,  IoU 0.4624
# EPOCH 51/100
# Validation . . .
# Loss 0.2840,  Acc 94.50,  IoU 0.4451
# EPOCH 52/100
# Validation . . .
# Loss 0.2224,  Acc 94.50,  IoU 0.4396
# EPOCH 53/100
# Validation . . .
# Loss 0.1629,  Acc 95.00,  IoU 0.4431
# EPOCH 54/100
# Validation . . .
# Loss 0.1873,  Acc 96.50,  IoU 0.5099
# EPOCH 55/100
# Validation . . .
# Loss 0.1625,  Acc 96.50,  IoU 0.5099
# EPOCH 56/100
# Validation . . .
# Loss 0.1936,  Acc 96.00,  IoU 0.5061
# EPOCH 57/100
# Validation . . .
# Loss 0.1596,  Acc 96.00,  IoU 0.5062
# EPOCH 58/100
# Validation . . .
# Loss 0.2147,  Acc 95.50,  IoU 0.5026
# EPOCH 59/100
# Validation . . .
# Loss 0.2188,  Acc 95.50,  IoU 0.5011
# EPOCH 60/100
# Validation . . .
# Loss 0.1939,  Acc 95.00,  IoU 0.5080
# EPOCH 61/100
# Validation . . .
# Loss 0.1974,  Acc 95.50,  IoU 0.5260
# EPOCH 62/100
# Validation . . .
# Loss 0.2313,  Acc 95.00,  IoU 0.5046
# EPOCH 63/100
# Validation . . .
# Loss 0.2642,  Acc 95.00,  IoU 0.5046
# EPOCH 64/100
# Validation . . .
# Loss 0.2268,  Acc 94.50,  IoU 0.4785
# EPOCH 65/100
# Validation . . .
# Loss 0.1795,  Acc 96.00,  IoU 0.5112
# EPOCH 66/100
# Validation . . .
# Loss 0.2297,  Acc 95.50,  IoU 0.5092
# EPOCH 67/100
# Validation . . .
# Loss 0.2418,  Acc 92.50,  IoU 0.4420
# EPOCH 68/100
# Validation . . .
# Loss 0.3074,  Acc 93.00,  IoU 0.4586
# EPOCH 69/100
# Validation . . .
# Loss 0.1758,  Acc 95.00,  IoU 0.5095
# EPOCH 70/100
# Validation . . .
# Loss 0.1899,  Acc 96.00,  IoU 0.5522
# EPOCH 71/100
# Validation . . .
# Loss 0.1693,  Acc 95.50,  IoU 0.5488
# EPOCH 72/100
# Validation . . .
# Loss 0.1736,  Acc 96.00,  IoU 0.5149
# EPOCH 73/100
# Validation . . .
# Loss 0.1906,  Acc 96.00,  IoU 0.4969
# EPOCH 74/100
# Validation . . .
# Loss 0.1538,  Acc 96.50,  IoU 0.4703
# EPOCH 75/100
# Validation . . .
# Loss 0.1894,  Acc 96.50,  IoU 0.5089
# EPOCH 76/100
# Validation . . .
# Loss 0.1765,  Acc 95.50,  IoU 0.4891
# EPOCH 77/100
# Validation . . .
# Loss 0.1599,  Acc 95.50,  IoU 0.5021
# EPOCH 78/100
# Validation . . .
# Loss 0.1637,  Acc 96.00,  IoU 0.5294
# EPOCH 79/100
# Validation . . .
# Loss 0.1841,  Acc 96.50,  IoU 0.5544
# EPOCH 80/100
# Validation . . .
# Loss 0.1755,  Acc 96.50,  IoU 0.5544
# EPOCH 81/100
# Validation . . .
# Loss 0.1783,  Acc 96.50,  IoU 0.5558
# EPOCH 82/100
# Validation . . .
# Loss 0.1633,  Acc 96.00,  IoU 0.5511
# EPOCH 83/100
# Validation . . .
# Loss 0.1721,  Acc 96.00,  IoU 0.5511
# EPOCH 84/100
# Validation . . .
# Loss 0.1460,  Acc 96.50,  IoU 0.4923
# EPOCH 85/100
# Validation . . .
# Loss 0.1358,  Acc 96.00,  IoU 0.4773
# EPOCH 86/100
# Validation . . .
# Loss 0.1723,  Acc 96.00,  IoU 0.4759
# EPOCH 87/100
# Validation . . .
# Loss 0.1579,  Acc 96.00,  IoU 0.4925
# EPOCH 88/100
# Validation . . .
# Loss 0.1587,  Acc 96.50,  IoU 0.5558
# EPOCH 89/100
# Validation . . .
# Loss 0.1377,  Acc 96.00,  IoU 0.5055
# EPOCH 90/100
# Validation . . .
# Loss 0.1404,  Acc 96.50,  IoU 0.5544
# EPOCH 91/100
# Validation . . .
# Loss 0.1457,  Acc 97.00,  IoU 0.5593
# EPOCH 92/100
# Validation . . .
# Loss 0.1612,  Acc 97.50,  IoU 0.5614
# EPOCH 93/100
# Validation . . .
# Loss 0.1316,  Acc 97.50,  IoU 0.5614
# EPOCH 94/100
# Validation . . .
# Loss 0.1057,  Acc 97.50,  IoU 0.5417
# EPOCH 95/100
# Validation . . .
# Loss 0.1102,  Acc 96.50,  IoU 0.5558
# EPOCH 96/100
# Validation . . .
# Loss 0.1529,  Acc 96.50,  IoU 0.5544
# EPOCH 97/100
# Validation . . .
# Loss 0.1569,  Acc 96.50,  IoU 0.5558
# EPOCH 98/100
# Validation . . .
# Loss 0.1695,  Acc 96.50,  IoU 0.5544
# EPOCH 99/100
# Validation . . .
# Loss 0.1233,  Acc 97.00,  IoU 0.5579
# EPOCH 100/100
# Validation . . .
# Loss 0.1593,  Acc 97.00,  IoU 0.5593
# Testing best epoch . . .
# Loss 0.1030,  Acc 97.50,  IoU 0.7739
# Starting Fold 3
# Train 5, Val 2, Test 2
# TOTAL TRAINABLE PARAMETERS : 164116
# RATIOS: Spatial  12.1% , Temporal  81.0% , Classifier   6.8%
# None
# EPOCH 1/100
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validation . . .
# Loss 3.4872,  Acc 2.50,  IoU 0.0032
# EPOCH 2/100
# Validation . . .
# Loss 3.8369,  Acc 2.50,  IoU 0.0031
# EPOCH 3/100
# Validation . . .
# Loss 3.2580,  Acc 2.50,  IoU 0.0036
# EPOCH 4/100
# Validation . . .
# Loss 2.4653,  Acc 4.00,  IoU 0.0094
# EPOCH 5/100
# Validation . . .
# Loss 1.9566,  Acc 25.50,  IoU 0.0889
# EPOCH 6/100
# Validation . . .
# Loss 1.5151,  Acc 39.50,  IoU 0.1161
# EPOCH 7/100
# Validation . . .
# Loss 1.3015,  Acc 60.50,  IoU 0.1934
# EPOCH 8/100
# Validation . . .
# Loss 1.1344,  Acc 72.00,  IoU 0.2198
# EPOCH 9/100
# Validation . . .
# Loss 1.0206,  Acc 78.50,  IoU 0.2685
# EPOCH 10/100
# Validation . . .
# Loss 0.8998,  Acc 83.50,  IoU 0.3322
# EPOCH 11/100
# Validation . . .
# Loss 0.7764,  Acc 88.50,  IoU 0.3570
# EPOCH 12/100
# Validation . . .
# Loss 0.7144,  Acc 90.50,  IoU 0.3712
# EPOCH 13/100
# Validation . . .
# Loss 0.6410,  Acc 92.50,  IoU 0.3895
# EPOCH 14/100
# Validation . . .
# Loss 0.5612,  Acc 92.00,  IoU 0.3742
# EPOCH 15/100
# Validation . . .
# Loss 0.5337,  Acc 94.50,  IoU 0.4490
# EPOCH 16/100
# Validation . . .
# Loss 0.4714,  Acc 93.50,  IoU 0.4227
# EPOCH 17/100
# Validation . . .
# Loss 0.4212,  Acc 94.00,  IoU 0.4309
# EPOCH 18/100
# Validation . . .
# Loss 0.3908,  Acc 93.50,  IoU 0.4235
# EPOCH 19/100
# Validation . . .
# Loss 0.3634,  Acc 93.50,  IoU 0.4332
# EPOCH 20/100
# Validation . . .
# Loss 0.3895,  Acc 94.00,  IoU 0.4365
# EPOCH 21/100
# Validation . . .
# Loss 0.3480,  Acc 93.00,  IoU 0.4531
# EPOCH 22/100
# Validation . . .
# Loss 0.3598,  Acc 94.50,  IoU 0.4853
# EPOCH 23/100
# Validation . . .
# Loss 0.3107,  Acc 94.50,  IoU 0.4671
# EPOCH 24/100
# Validation . . .
# Loss 0.3101,  Acc 94.50,  IoU 0.4671
# EPOCH 25/100
# Validation . . .
# Loss 0.2850,  Acc 93.50,  IoU 0.4299
# EPOCH 26/100
# Validation . . .
# Loss 0.2881,  Acc 93.50,  IoU 0.4299
# EPOCH 27/100
# Validation . . .
# Loss 0.2680,  Acc 95.00,  IoU 0.4705
# EPOCH 28/100
# Validation . . .
# Loss 0.2324,  Acc 95.00,  IoU 0.4705
# EPOCH 29/100
# Validation . . .
# Loss 0.2604,  Acc 93.50,  IoU 0.4306
# EPOCH 30/100
# Validation . . .
# Loss 0.2827,  Acc 93.50,  IoU 0.4306
# EPOCH 31/100
# Validation . . .
# Loss 0.2386,  Acc 94.00,  IoU 0.4341
# EPOCH 32/100
# Validation . . .
# Loss 0.2029,  Acc 95.50,  IoU 0.4740
# EPOCH 33/100
# Validation . . .
# Loss 0.2412,  Acc 95.00,  IoU 0.4705
# EPOCH 34/100
# Validation . . .
# Loss 0.2764,  Acc 95.00,  IoU 0.4705
# EPOCH 35/100
# Validation . . .
# Loss 0.2522,  Acc 95.50,  IoU 0.4740
# EPOCH 36/100
# Validation . . .
# Loss 0.2254,  Acc 95.50,  IoU 0.4740
# EPOCH 37/100
# Validation . . .
# Loss 0.2454,  Acc 93.50,  IoU 0.4194
# EPOCH 38/100
# Validation . . .
# Loss 0.2361,  Acc 93.50,  IoU 0.4024
# EPOCH 39/100
# Validation . . .
# Loss 0.2275,  Acc 94.00,  IoU 0.4314
# EPOCH 40/100
# Validation . . .
# Loss 0.2465,  Acc 95.00,  IoU 0.4705
# EPOCH 41/100
# Validation . . .
# Loss 0.2274,  Acc 95.50,  IoU 0.4740
# EPOCH 42/100
# Validation . . .
# Loss 0.2380,  Acc 94.50,  IoU 0.4478
# EPOCH 43/100
# Validation . . .
# Loss 0.2737,  Acc 94.00,  IoU 0.4251
# EPOCH 44/100
# Validation . . .
# Loss 0.2802,  Acc 94.00,  IoU 0.4172
# EPOCH 45/100
# Validation . . .
# Loss 0.2592,  Acc 93.50,  IoU 0.4249
# EPOCH 46/100
# Validation . . .
# Loss 0.3047,  Acc 93.00,  IoU 0.4162
# EPOCH 47/100
# Validation . . .
# Loss 0.2809,  Acc 93.00,  IoU 0.4285
# EPOCH 48/100
# Validation . . .
# Loss 0.3293,  Acc 93.00,  IoU 0.4285
# EPOCH 49/100
# Validation . . .
# Loss 0.2307,  Acc 94.00,  IoU 0.4314
# EPOCH 50/100
# Validation . . .
# Loss 0.2494,  Acc 93.50,  IoU 0.4281
# EPOCH 51/100
# Validation . . .
# Loss 0.2257,  Acc 94.50,  IoU 0.4331
# EPOCH 52/100
# Validation . . .
# Loss 0.2631,  Acc 94.50,  IoU 0.4348
# EPOCH 53/100
# Validation . . .
# Loss 0.2637,  Acc 95.00,  IoU 0.4705
# EPOCH 54/100
# Validation . . .
# Loss 0.1879,  Acc 95.00,  IoU 0.4705
# EPOCH 55/100
# Validation . . .
# Loss 0.2020,  Acc 94.50,  IoU 0.4671
# EPOCH 56/100
# Validation . . .
# Loss 0.2002,  Acc 94.50,  IoU 0.4671
# EPOCH 57/100
# Validation . . .
# Loss 0.2084,  Acc 94.00,  IoU 0.4508
# EPOCH 58/100
# Validation . . .
# Loss 0.2368,  Acc 94.50,  IoU 0.4671
# EPOCH 59/100
# Validation . . .
# Loss 0.2319,  Acc 95.00,  IoU 0.4705
# EPOCH 60/100
# Validation . . .
# Loss 0.2465,  Acc 94.50,  IoU 0.4671
# EPOCH 61/100
# Validation . . .
# Loss 0.2150,  Acc 95.00,  IoU 0.4705
# EPOCH 62/100
# Validation . . .
# Loss 0.2413,  Acc 95.00,  IoU 0.4705
# EPOCH 63/100
# Validation . . .
# Loss 0.2530,  Acc 95.00,  IoU 0.4703
# EPOCH 64/100
# Validation . . .
# Loss 0.2195,  Acc 95.00,  IoU 0.4703
# EPOCH 65/100
# Validation . . .
# Loss 0.2188,  Acc 95.00,  IoU 0.4703
# EPOCH 66/100
# Validation . . .
# Loss 0.2249,  Acc 95.00,  IoU 0.4703
# EPOCH 67/100
# Validation . . .
# Loss 0.1775,  Acc 95.00,  IoU 0.4703
# EPOCH 68/100
# Validation . . .
# Loss 0.2046,  Acc 95.00,  IoU 0.4703
# EPOCH 69/100
# Validation . . .
# Loss 0.2447,  Acc 95.50,  IoU 0.4740
# EPOCH 70/100
# Validation . . .
# Loss 0.2068,  Acc 95.00,  IoU 0.4705
# EPOCH 71/100
# Validation . . .
# Loss 0.2525,  Acc 95.50,  IoU 0.4740
# EPOCH 72/100
# Validation . . .
# Loss 0.2347,  Acc 94.50,  IoU 0.4059
# EPOCH 73/100
# Validation . . .
# Loss 0.2129,  Acc 93.50,  IoU 0.3964
# EPOCH 74/100
# Validation . . .
# Loss 0.2640,  Acc 93.50,  IoU 0.3991
# EPOCH 75/100
# Validation . . .
# Loss 0.2331,  Acc 94.00,  IoU 0.3998
# EPOCH 76/100
# Validation . . .
# Loss 0.2734,  Acc 94.00,  IoU 0.4070
# EPOCH 77/100
# Validation . . .
# Loss 0.2866,  Acc 93.50,  IoU 0.4194
# EPOCH 78/100
# Validation . . .
# Loss 0.2681,  Acc 93.50,  IoU 0.4113
# EPOCH 79/100
# Validation . . .
# Loss 0.3026,  Acc 94.00,  IoU 0.4404
# EPOCH 80/100
# Validation . . .
# Loss 0.2556,  Acc 94.50,  IoU 0.4348
# EPOCH 81/100
# Validation . . .
# Loss 0.2749,  Acc 94.00,  IoU 0.4218
# EPOCH 82/100
# Validation . . .
# Loss 0.2585,  Acc 93.50,  IoU 0.4045
# EPOCH 83/100
# Validation . . .
# Loss 0.3172,  Acc 92.50,  IoU 0.3935
# EPOCH 84/100
# Validation . . .
# Loss 0.3338,  Acc 91.50,  IoU 0.3814
# EPOCH 85/100
# Validation . . .
# Loss 0.2568,  Acc 93.00,  IoU 0.4063
# EPOCH 86/100
# Validation . . .
# Loss 0.2801,  Acc 93.00,  IoU 0.3985
# EPOCH 87/100
# Validation . . .
# Loss 0.2411,  Acc 94.00,  IoU 0.3964
# EPOCH 88/100
# Validation . . .
# Loss 0.2091,  Acc 93.00,  IoU 0.3885
# EPOCH 89/100
# Validation . . .
# Loss 0.2147,  Acc 93.50,  IoU 0.3919
# EPOCH 90/100
# Validation . . .
# Loss 0.2517,  Acc 94.00,  IoU 0.3955
# EPOCH 91/100
# Validation . . .
# Loss 0.2817,  Acc 94.00,  IoU 0.4149
# EPOCH 92/100
# Validation . . .
# Loss 0.2409,  Acc 94.00,  IoU 0.4149
# EPOCH 93/100
# Validation . . .
# Loss 0.2272,  Acc 94.00,  IoU 0.4471
# EPOCH 94/100
# Validation . . .
# Loss 0.2514,  Acc 94.50,  IoU 0.4683
# EPOCH 95/100
# Validation . . .
# Loss 0.2668,  Acc 95.00,  IoU 0.4897
# EPOCH 96/100
# Validation . . .
# Loss 0.2343,  Acc 95.00,  IoU 0.4897
# EPOCH 97/100
# Validation . . .
# Loss 0.2881,  Acc 93.50,  IoU 0.4324
# EPOCH 98/100
# Validation . . .
# Loss 0.2603,  Acc 95.00,  IoU 0.4784
# EPOCH 99/100
# Validation . . .
# Loss 0.2832,  Acc 95.00,  IoU 0.4706
# EPOCH 100/100
# Validation . . .
# Loss 0.2006,  Acc 95.50,  IoU 0.4740
# Testing best epoch . . .
# Loss 0.3110,  Acc 92.96,  IoU 0.4181
# Starting Fold 4
# Train 5, Val 2, Test 2
# TOTAL TRAINABLE PARAMETERS : 164116
# RATIOS: Spatial  12.1% , Temporal  81.0% , Classifier   6.8%
# None
# EPOCH 1/100
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validation . . .
# Loss 2.8503,  Acc 0.50,  IoU 0.0006
# EPOCH 2/100
# Validation . . .
# Loss 3.0409,  Acc 18.00,  IoU 0.0608
# EPOCH 3/100
# Validation . . .
# Loss 3.3862,  Acc 23.00,  IoU 0.0483
# EPOCH 4/100
# Validation . . .
# Loss 3.2815,  Acc 24.50,  IoU 0.0490
# EPOCH 5/100
# Validation . . .
# Loss 2.8509,  Acc 25.00,  IoU 0.0510
# EPOCH 6/100
# Validation . . .
# Loss 2.2799,  Acc 25.00,  IoU 0.0611
# EPOCH 7/100
# Validation . . .
# Loss 1.8666,  Acc 26.50,  IoU 0.0720
# EPOCH 8/100
# Validation . . .
# Loss 1.5730,  Acc 41.00,  IoU 0.1731
# EPOCH 9/100
# Validation . . .
# Loss 1.3646,  Acc 63.50,  IoU 0.2282
# EPOCH 10/100
# Validation . . .
# Loss 1.1475,  Acc 77.50,  IoU 0.2500
# EPOCH 11/100
# Validation . . .
# Loss 0.9828,  Acc 84.50,  IoU 0.2631
# EPOCH 12/100
# Validation . . .
# Loss 0.8641,  Acc 88.50,  IoU 0.2732
# EPOCH 13/100
# Validation . . .
# Loss 0.7579,  Acc 90.00,  IoU 0.3508
# EPOCH 14/100
# Validation . . .
# Loss 0.7068,  Acc 91.00,  IoU 0.3492
# EPOCH 15/100
# Validation . . .
# Loss 0.6525,  Acc 91.50,  IoU 0.3563
# EPOCH 16/100
# Validation . . .
# Loss 0.5599,  Acc 92.00,  IoU 0.3463
# EPOCH 17/100
# Validation . . .
# Loss 0.4843,  Acc 92.00,  IoU 0.3595
# EPOCH 18/100
# Validation . . .
# Loss 0.4474,  Acc 92.00,  IoU 0.3483
# EPOCH 19/100
# Validation . . .
# Loss 0.4451,  Acc 92.00,  IoU 0.3822
# EPOCH 20/100
# Validation . . .
# Loss 0.3782,  Acc 93.00,  IoU 0.3687
# EPOCH 21/100
# Validation . . .
# Loss 0.3609,  Acc 93.50,  IoU 0.3930
# EPOCH 22/100
# Validation . . .
# Loss 0.3418,  Acc 93.00,  IoU 0.3700
# EPOCH 23/100
# Validation . . .
# Loss 0.2705,  Acc 94.00,  IoU 0.3923
# EPOCH 24/100
# Validation . . .
# Loss 0.3114,  Acc 94.50,  IoU 0.4203
# EPOCH 25/100
# Validation . . .
# Loss 0.2623,  Acc 95.00,  IoU 0.4816
# EPOCH 26/100
# Validation . . .
# Loss 0.2487,  Acc 96.00,  IoU 0.5112
# EPOCH 27/100
# Validation . . .
# Loss 0.2464,  Acc 95.50,  IoU 0.4721
# EPOCH 28/100
# Validation . . .
# Loss 0.2805,  Acc 94.00,  IoU 0.4290
# EPOCH 29/100
# Validation . . .
# Loss 0.2706,  Acc 93.50,  IoU 0.4341
# EPOCH 30/100
# Validation . . .
# Loss 0.2612,  Acc 93.50,  IoU 0.4223
# EPOCH 31/100
# Validation . . .
# Loss 0.2261,  Acc 96.00,  IoU 0.4967
# EPOCH 32/100
# Validation . . .
# Loss 0.2498,  Acc 95.00,  IoU 0.4406
# EPOCH 33/100
# Validation . . .
# Loss 0.2338,  Acc 95.00,  IoU 0.4406
# EPOCH 34/100
# Validation . . .
# Loss 0.2391,  Acc 94.50,  IoU 0.4371
# EPOCH 35/100
# Validation . . .
# Loss 0.2129,  Acc 94.50,  IoU 0.4115
# EPOCH 36/100
# Validation . . .
# Loss 0.2099,  Acc 94.50,  IoU 0.4047
# EPOCH 37/100
# Validation . . .
# Loss 0.2238,  Acc 93.50,  IoU 0.4278
# EPOCH 38/100
# Validation . . .
# Loss 0.2260,  Acc 94.50,  IoU 0.4431
# EPOCH 39/100
# Validation . . .
# Loss 0.1827,  Acc 95.00,  IoU 0.4575
# EPOCH 40/100
# Validation . . .
# Loss 0.2348,  Acc 94.50,  IoU 0.4538
# EPOCH 41/100
# Validation . . .
# Loss 0.2185,  Acc 94.00,  IoU 0.4636
# EPOCH 42/100
# Validation . . .
# Loss 0.2573,  Acc 93.00,  IoU 0.3932
# EPOCH 43/100
# Validation . . .
# Loss 0.2322,  Acc 95.00,  IoU 0.4280
# EPOCH 44/100
# Validation . . .
# Loss 0.2226,  Acc 95.50,  IoU 0.4723
# EPOCH 45/100
# Validation . . .
# Loss 0.2630,  Acc 94.00,  IoU 0.4416
# EPOCH 46/100
# Validation . . .
# Loss 0.2792,  Acc 93.50,  IoU 0.4386
# EPOCH 47/100
# Validation . . .
# Loss 0.2805,  Acc 93.00,  IoU 0.4463
# EPOCH 48/100
# Validation . . .
# Loss 0.2245,  Acc 94.50,  IoU 0.4998
# EPOCH 49/100
# Validation . . .
# Loss 0.2071,  Acc 94.50,  IoU 0.4669
# EPOCH 50/100
# Validation . . .
# Loss 0.2183,  Acc 94.50,  IoU 0.4486
# EPOCH 51/100
# Validation . . .
# Loss 0.2083,  Acc 96.00,  IoU 0.5327
# EPOCH 52/100
# Validation . . .
# Loss 0.2369,  Acc 96.00,  IoU 0.5134
# EPOCH 53/100
# Validation . . .
# Loss 0.2301,  Acc 95.50,  IoU 0.5097
# EPOCH 54/100
# Validation . . .
# Loss 0.2647,  Acc 94.50,  IoU 0.4276
# EPOCH 55/100
# Validation . . .
# Loss 0.2622,  Acc 95.00,  IoU 0.4463
# EPOCH 56/100
# Validation . . .
# Loss 0.1984,  Acc 93.50,  IoU 0.4339
# EPOCH 57/100
# Validation . . .
# Loss 0.2142,  Acc 93.50,  IoU 0.4401
# EPOCH 58/100
# Validation . . .
# Loss 0.2137,  Acc 96.00,  IoU 0.4504
# EPOCH 59/100
# Validation . . .
# Loss 0.2353,  Acc 94.50,  IoU 0.4452
# EPOCH 60/100
# Validation . . .
# Loss 0.2136,  Acc 95.50,  IoU 0.4643
# EPOCH 61/100
# Validation . . .
# Loss 0.1708,  Acc 95.50,  IoU 0.4324
# EPOCH 62/100
# Validation . . .
# Loss 0.1487,  Acc 95.50,  IoU 0.4312
# EPOCH 63/100
# Validation . . .
# Loss 0.1609,  Acc 95.50,  IoU 0.4639
# EPOCH 64/100
# Validation . . .
# Loss 0.2344,  Acc 95.00,  IoU 0.5064
# EPOCH 65/100
# Validation . . .
# Loss 0.2021,  Acc 94.50,  IoU 0.4552
# EPOCH 66/100
# Validation . . .
# Loss 0.1839,  Acc 96.00,  IoU 0.5185
# EPOCH 67/100
# Validation . . .
# Loss 0.1433,  Acc 96.50,  IoU 0.4892
# EPOCH 68/100
# Validation . . .
# Loss 0.1660,  Acc 96.00,  IoU 0.4505
# EPOCH 69/100
# Validation . . .
# Loss 0.1474,  Acc 96.50,  IoU 0.4892
# EPOCH 70/100
# Validation . . .
# Loss 0.1433,  Acc 96.50,  IoU 0.4892
# EPOCH 71/100
# Validation . . .
# Loss 0.1371,  Acc 96.00,  IoU 0.4505
# EPOCH 72/100
# Validation . . .
# Loss 0.1961,  Acc 96.50,  IoU 0.4403
# EPOCH 73/100
# Validation . . .
# Loss 0.1625,  Acc 96.00,  IoU 0.4370
# EPOCH 74/100
# Validation . . .
# Loss 0.1684,  Acc 96.00,  IoU 0.4370
# EPOCH 75/100
# Validation . . .
# Loss 0.1624,  Acc 95.50,  IoU 0.4324
# EPOCH 76/100
# Validation . . .
# Loss 0.2030,  Acc 95.00,  IoU 0.4057
# EPOCH 77/100
# Validation . . .
# Loss 0.1678,  Acc 95.50,  IoU 0.4340
# EPOCH 78/100
# Validation . . .
# Loss 0.1672,  Acc 96.50,  IoU 0.4915
# EPOCH 79/100
# Validation . . .
# Loss 0.1882,  Acc 95.50,  IoU 0.4665
# EPOCH 80/100
# Validation . . .
# Loss 0.1864,  Acc 95.50,  IoU 0.4516
# EPOCH 81/100
# Validation . . .
# Loss 0.1727,  Acc 95.50,  IoU 0.4516
# EPOCH 82/100
# Validation . . .
# Loss 0.1628,  Acc 95.50,  IoU 0.4516
# EPOCH 83/100
# Validation . . .
# Loss 0.1472,  Acc 95.00,  IoU 0.4455
# EPOCH 84/100
# Validation . . .
# Loss 0.1417,  Acc 95.50,  IoU 0.4391
# EPOCH 85/100
# Validation . . .
# Loss 0.1931,  Acc 95.00,  IoU 0.4247
# EPOCH 86/100
# Validation . . .
# Loss 0.1424,  Acc 96.50,  IoU 0.4891
# EPOCH 87/100
# Validation . . .
# Loss 0.1259,  Acc 96.50,  IoU 0.4915
# EPOCH 88/100
# Validation . . .
# Loss 0.1542,  Acc 96.50,  IoU 0.4336
# EPOCH 89/100
# Validation . . .
# Loss 0.1379,  Acc 96.50,  IoU 0.4878
# EPOCH 90/100
# Validation . . .
# Loss 0.1473,  Acc 96.50,  IoU 0.4878
# EPOCH 91/100
# Validation . . .
# Loss 0.1513,  Acc 96.50,  IoU 0.4891
# EPOCH 92/100
# Validation . . .
# Loss 0.1986,  Acc 96.50,  IoU 0.4891
# EPOCH 93/100
# Validation . . .
# Loss 0.1742,  Acc 95.50,  IoU 0.4287
# EPOCH 94/100
# Validation . . .
# Loss 0.1818,  Acc 96.00,  IoU 0.4495
# EPOCH 95/100
# Validation . . .
# Loss 0.2145,  Acc 95.50,  IoU 0.4168
# EPOCH 96/100
# Validation . . .
# Loss 0.1988,  Acc 95.50,  IoU 0.5158
# EPOCH 97/100
# Validation . . .
# Loss 0.2413,  Acc 95.00,  IoU 0.4433
# EPOCH 98/100
# Validation . . .
# Loss 0.2502,  Acc 94.50,  IoU 0.4363
# EPOCH 99/100
# Validation . . .
# Loss 0.2867,  Acc 93.50,  IoU 0.4304
# EPOCH 100/100
# Validation . . .
# Loss 0.3255,  Acc 92.50,  IoU 0.3833
# Testing best epoch . . .
# Loss 0.1578,  Acc 95.48,  IoU 0.8847
# Starting Fold 5
# Train 5, Val 2, Test 2
# TOTAL TRAINABLE PARAMETERS : 164116
# RATIOS: Spatial  12.1% , Temporal  81.0% , Classifier   6.8%
# None
# EPOCH 1/100
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:557: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
# Validation . . .
# Loss 3.2825,  Acc 0.00,  IoU 0.0000
# EPOCH 2/100
# Validation . . .
# Loss 3.2023,  Acc 0.00,  IoU 0.0000
# EPOCH 3/100
# Validation . . .
# Loss 3.2609,  Acc 0.00,  IoU 0.0000
# EPOCH 4/100
# Validation . . .
# Loss 2.9519,  Acc 1.50,  IoU 0.0044
# EPOCH 5/100
# Validation . . .
# Loss 2.3348,  Acc 15.50,  IoU 0.0453
# EPOCH 6/100
# Validation . . .
# Loss 1.7985,  Acc 32.50,  IoU 0.0950
# EPOCH 7/100
# Validation . . .
# Loss 1.5692,  Acc 38.50,  IoU 0.0965
# EPOCH 8/100
# Validation . . .
# Loss 1.4319,  Acc 49.50,  IoU 0.1611
# EPOCH 9/100
# Validation . . .
# Loss 1.3001,  Acc 65.00,  IoU 0.2459
# EPOCH 10/100
# Validation . . .
# Loss 1.1545,  Acc 72.00,  IoU 0.2819
# EPOCH 11/100
# Validation . . .
# Loss 1.0349,  Acc 74.00,  IoU 0.2783
# EPOCH 12/100
# Validation . . .
# Loss 0.9620,  Acc 76.00,  IoU 0.2844
# EPOCH 13/100
# Validation . . .
# Loss 0.7894,  Acc 81.00,  IoU 0.3059
# EPOCH 14/100
# Validation . . .
# Loss 0.6949,  Acc 83.50,  IoU 0.3295
# EPOCH 15/100
# Validation . . .
# Loss 0.7050,  Acc 84.50,  IoU 0.3314
# EPOCH 16/100
# Validation . . .
# Loss 0.6464,  Acc 85.50,  IoU 0.3718
# EPOCH 17/100
# Validation . . .
# Loss 0.5637,  Acc 88.00,  IoU 0.4094
# EPOCH 18/100
# Validation . . .
# Loss 0.5149,  Acc 88.50,  IoU 0.4145
# EPOCH 19/100
# Validation . . .
# Loss 0.5138,  Acc 89.00,  IoU 0.4500
# EPOCH 20/100
# Validation . . .
# Loss 0.4518,  Acc 91.50,  IoU 0.4836
# EPOCH 21/100
# Validation . . .
# Loss 0.4537,  Acc 91.00,  IoU 0.4900
# EPOCH 22/100
# Validation . . .
# Loss 0.4145,  Acc 92.00,  IoU 0.5022
# EPOCH 23/100
# Validation . . .
# Loss 0.4211,  Acc 92.00,  IoU 0.5775
# EPOCH 24/100
# Validation . . .
# Loss 0.3548,  Acc 93.50,  IoU 0.5900
# EPOCH 25/100
# Validation . . .
# Loss 0.3729,  Acc 92.50,  IoU 0.4940
# EPOCH 26/100
# Validation . . .
# Loss 0.3841,  Acc 91.00,  IoU 0.5405
# EPOCH 27/100
# Validation . . .
# Loss 0.2967,  Acc 93.00,  IoU 0.5438
# EPOCH 28/100
# Validation . . .
# Loss 0.3039,  Acc 92.00,  IoU 0.5105
# EPOCH 29/100
# Validation . . .
# Loss 0.3254,  Acc 93.00,  IoU 0.6097
# EPOCH 30/100
# Validation . . .
# Loss 0.2892,  Acc 93.50,  IoU 0.6403
# EPOCH 31/100
# Validation . . .
# Loss 0.3015,  Acc 93.50,  IoU 0.5397
# EPOCH 32/100
# Validation . . .
# Loss 0.2941,  Acc 93.00,  IoU 0.7733
# EPOCH 33/100
# Validation . . .
# Loss 0.2669,  Acc 93.50,  IoU 0.8007
# EPOCH 34/100
# Validation . . .
# Loss 0.2744,  Acc 93.50,  IoU 0.5404
# EPOCH 35/100
# Validation . . .
# Loss 0.2217,  Acc 95.00,  IoU 0.5676
# EPOCH 36/100
# Validation . . .
# Loss 0.2355,  Acc 95.00,  IoU 0.5423
# EPOCH 37/100
# Validation . . .
# Loss 0.2612,  Acc 93.00,  IoU 0.6237
# EPOCH 38/100
# Validation . . .
# Loss 0.2283,  Acc 92.50,  IoU 0.6192
# EPOCH 39/100
# Validation . . .
# Loss 0.2321,  Acc 93.50,  IoU 0.6372
# EPOCH 40/100
# Validation . . .
# Loss 0.2700,  Acc 93.50,  IoU 0.6294
# EPOCH 41/100
# Validation . . .
# Loss 0.2263,  Acc 94.00,  IoU 0.6414
# EPOCH 42/100
# Validation . . .
# Loss 0.2165,  Acc 94.50,  IoU 0.8039
# EPOCH 43/100
# Validation . . .
# Loss 0.1960,  Acc 94.50,  IoU 0.6447
# EPOCH 44/100
# Validation . . .
# Loss 0.2588,  Acc 93.50,  IoU 0.7927
# EPOCH 45/100
# Validation . . .
# Loss 0.2361,  Acc 93.50,  IoU 0.7927
# EPOCH 46/100
# Validation . . .
# Loss 0.2545,  Acc 93.00,  IoU 0.6313
# EPOCH 47/100
# Validation . . .
# Loss 0.2656,  Acc 93.00,  IoU 0.7878
# EPOCH 48/100
# Validation . . .
# Loss 0.2390,  Acc 94.00,  IoU 0.6506
# EPOCH 49/100
# Validation . . .
# Loss 0.2323,  Acc 94.50,  IoU 0.6447
# EPOCH 50/100
# Validation . . .
# Loss 0.2250,  Acc 94.50,  IoU 0.8116
# EPOCH 51/100
# Validation . . .
# Loss 0.2196,  Acc 93.50,  IoU 0.7933
# EPOCH 52/100
# Validation . . .
# Loss 0.2342,  Acc 94.00,  IoU 0.8174
# EPOCH 53/100
# Validation . . .
# Loss 0.2246,  Acc 94.00,  IoU 0.7983
# EPOCH 54/100
# Validation . . .
# Loss 0.2140,  Acc 94.50,  IoU 0.6735
# EPOCH 55/100
# Validation . . .
# Loss 0.1642,  Acc 94.00,  IoU 0.5348
# EPOCH 56/100
# Validation . . .
# Loss 0.1938,  Acc 94.50,  IoU 0.5512
# EPOCH 57/100
# Validation . . .
# Loss 0.1907,  Acc 94.50,  IoU 0.6298
# EPOCH 58/100
# Validation . . .
# Loss 0.1931,  Acc 94.00,  IoU 0.5224
# EPOCH 59/100
# Validation . . .
# Loss 0.2106,  Acc 94.00,  IoU 0.6254
# EPOCH 60/100
# Validation . . .
# Loss 0.2293,  Acc 93.50,  IoU 0.5187
# EPOCH 61/100
# Validation . . .
# Loss 0.1993,  Acc 94.50,  IoU 0.6529
# EPOCH 62/100
# Validation . . .
# Loss 0.2371,  Acc 92.50,  IoU 0.6353
# EPOCH 63/100
# Validation . . .
# Loss 0.2423,  Acc 94.00,  IoU 0.8301
# EPOCH 64/100
# Validation . . .
# Loss 0.1907,  Acc 94.50,  IoU 0.6838
# EPOCH 65/100
# Validation . . .
# Loss 0.2154,  Acc 95.00,  IoU 0.7050
# EPOCH 66/100
# Validation . . .
# Loss 0.2417,  Acc 94.50,  IoU 0.7320
# EPOCH 67/100
# Validation . . .
# Loss 0.2411,  Acc 93.50,  IoU 0.8346
# EPOCH 68/100
# Validation . . .
# Loss 0.1488,  Acc 96.00,  IoU 0.9111
# EPOCH 69/100
# Validation . . .
# Loss 0.1742,  Acc 95.00,  IoU 0.8414
# EPOCH 70/100
# Validation . . .
# Loss 0.2014,  Acc 95.00,  IoU 0.8177
# EPOCH 71/100
# Validation . . .
# Loss 0.1751,  Acc 93.50,  IoU 0.7745
# EPOCH 72/100
# Validation . . .
# Loss 0.2411,  Acc 92.50,  IoU 0.7943
# EPOCH 73/100
# Validation . . .
# Loss 0.1764,  Acc 94.00,  IoU 0.8338
# EPOCH 74/100
# Validation . . .
# Loss 0.1702,  Acc 94.00,  IoU 0.8098
# EPOCH 75/100
# Validation . . .
# Loss 0.1766,  Acc 95.00,  IoU 0.8619
# EPOCH 76/100
# Validation . . .
# Loss 0.2126,  Acc 93.50,  IoU 0.8455
# EPOCH 77/100
# Validation . . .
# Loss 0.2502,  Acc 90.50,  IoU 0.7602
# EPOCH 78/100
# Validation . . .
# Loss 0.1626,  Acc 95.00,  IoU 0.8473
# EPOCH 79/100
# Validation . . .
# Loss 0.1521,  Acc 95.00,  IoU 0.8473
# EPOCH 80/100
# Validation . . .
# Loss 0.1228,  Acc 96.50,  IoU 0.9022
# EPOCH 81/100
# Validation . . .
# Loss 0.1449,  Acc 95.50,  IoU 0.8478
# EPOCH 82/100
# Validation . . .
# Loss 0.1331,  Acc 95.50,  IoU 0.5761
# EPOCH 83/100
# Validation . . .
# Loss 0.1444,  Acc 95.50,  IoU 0.5838
# EPOCH 84/100
# Validation . . .
# Loss 0.1366,  Acc 96.50,  IoU 0.6139
# EPOCH 85/100
# Validation . . .
# Loss 0.1877,  Acc 95.50,  IoU 0.5751
# EPOCH 86/100
# Validation . . .
# Loss 0.1506,  Acc 96.50,  IoU 0.6012
# EPOCH 87/100
# Validation . . .
# Loss 0.1656,  Acc 95.00,  IoU 0.4992
# EPOCH 88/100
# Validation . . .
# Loss 0.1735,  Acc 95.50,  IoU 0.5154
# EPOCH 89/100
# Validation . . .
# Loss 0.1427,  Acc 96.00,  IoU 0.5175
# EPOCH 90/100
# Validation . . .
# Loss 0.1372,  Acc 95.50,  IoU 0.5636
# EPOCH 91/100
# Validation . . .
# Loss 0.1615,  Acc 93.50,  IoU 0.5371
# EPOCH 92/100
# Validation . . .
# Loss 0.1732,  Acc 94.50,  IoU 0.5625
# EPOCH 93/100
# Validation . . .
# Loss 0.1368,  Acc 94.50,  IoU 0.6645
# EPOCH 94/100
# Validation . . .
# Loss 0.1430,  Acc 95.00,  IoU 0.6690
# EPOCH 95/100
# Validation . . .
# Loss 0.1596,  Acc 95.00,  IoU 0.6780
# EPOCH 96/100
# Validation . . .
# Loss 0.1354,  Acc 96.00,  IoU 0.6918
# EPOCH 97/100
# Validation . . .
# Loss 0.1593,  Acc 95.00,  IoU 0.6690
# EPOCH 98/100
# Validation . . .
# Loss 0.1695,  Acc 94.50,  IoU 0.6645
# EPOCH 99/100
# Validation . . .
# Loss 0.1952,  Acc 95.00,  IoU 0.6780
# EPOCH 100/100
# Validation . . .
# Loss 0.1743,  Acc 94.50,  IoU 0.6735
# Testing best epoch . . .
# Loss 0.1533,  Acc 95.48,  IoU 0.4721
# Overall performance:
# Acc: 0.950852557673019,  IoU: 0.3580005203373844
# /content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/learning/metrics.py:61: RuntimeWarning: invalid value encountered in double_scalars
#   d['Precision'] = tp / (tp + fp)
# /content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/learning/metrics.py:60: RuntimeWarning: invalid value encountered in double_scalars
#   d['IoU'] = tp / (tp + fp + fn)
# /content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/learning/metrics.py:62: RuntimeWarning: invalid value encountered in double_scalars
#   d['Recall'] = tp / (tp + fn)
# /content/drive/MyDrive/Articles/Satellite_Image_TimeSeriesClassification/learning/metrics.py:63: RuntimeWarning: invalid value encountered in double_scalars
#   d['F1-score'] = 2 * tp / (2 * tp + fp + fn)
